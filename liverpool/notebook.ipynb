# %%
import pandas as pd

# %%
# %run ../peak_age_plot/plot_peak_age.py
# %run ../peak_age_plot/tmkt_to_df.py

# %%
df = tmkt_to_df("liverpool.html")

# %%
df.to_csv("data.csv", index=False)

# %%
df = pd.read_csv("data_manual_modify.csv")

# %%
plot_peak_age(df, "Liverpool")
